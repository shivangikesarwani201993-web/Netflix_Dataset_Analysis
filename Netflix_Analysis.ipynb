# %% [markdown]
# 1) Overall Data Analysis 📊

# %% [markdown]
# 1.1) Importing the necessary Liabraries 🧰

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1.2) Loading the dataset - Netflix Dataset 📂

# %%
df = pd.read_csv("/content/sample_data/netflix_titles.csv")

# %% [markdown]
# 1.3) Viewing the data using head(), tail(), sample() and info() 🧾

# %%
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
df.tail()
# Out:
#      show_id     type                                    title     director  \
# 7782   s7783    Movie                                     Zozo  Josef Fares
# 7783   s7784    Movie                                   Zubaan  Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan          NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    cast  \
# 7782  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                            Nasty C
# 7785                         Adriano Zumbo, Rachel Khoo
# 7786                                                NaN
#
#                                                 country          date_added  \
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating  duration  \
# 7782          2005  TV-MA    99 min
# 7783          2015  TV-14   111 min
# 7784          2019  TV-MA    44 min
# 7785          2019  TV-PG  1 Season
# 7786          2019  TV-MA    90 min
#
#                                               listed_in  \
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...

# %%
df.sample(10)
# Out:
#      show_id     type                                     title  \
# 129     s130    Movie                                     6-5=2
# 5799   s5800  TV Show                                  Start-Up
# 3531   s3532  TV Show  Larry Charles' Dangerous World of Comedy
# 7638   s7639    Movie                             Winter's Bone
# 394     s395    Movie                              Alice Junior
# 2261   s2262  TV Show     Frank Elstner: Just One Last Question
# 4630   s4631  TV Show                          Once Upon a Time
# 6801   s6802  TV Show                                 The Ranch
# 6930   s6931    Movie                          The Time Machine
# 6027   s6028    Movie                                     Terra
#
#                                   director  \
# 129                            Bharat Jain
# 5799                                   NaN
# 3531                                   NaN
# 7638                          Debra Granik
# 394                             Gil Baroni
# 2261                                   NaN
# 4630                                   NaN
# 6801                                   NaN
# 6930                           Simon Wells
# 6027  Yann Arthus-Bertrand, Michael Pitiot
#
#                                                    cast  \
# 129   Prashantt Guptha, Gaurav Paswala, Gaurav Kotha...
# 5799  Bae Suzy, Nam Joo-hyuk, Kim Seon-ho, Kang Han-...
# 3531                                      Larry Charles
# 7638  Jennifer Lawrence, John Hawkes, Kevin Breznaha...
# 394   Anne Celestino Mota, Emmanuel Rosset, Matheus ...
# 2261  Klaas Heufer-Umlauf, Joko Winterscheidt, Lena ...
# 4630  Ruby, Mohamed Farraag, Ahmed Dawood, Sawsan Ba...
# 6801  Ashton Kutcher, Sam Elliott, Debra Winger, Eli...
# 6930  Guy Pearce, Samantha Mumba, Jeremy Irons, Mark...
# 6027                                    Vanessa Paradis
#
#                                   country         date_added  release_year  \
# 129                                 India   November 1, 2017          2014
# 5799                          South Korea   October 18, 2020          2020
# 3531                                  NaN  February 15, 2019          2019
# 7638                        United States      March 1, 2019          2010
# 394                                Brazil   October 23, 2020          2019
# 2261                              Germany      June 12, 2020          2020
# 4630                                Egypt   December 9, 2020          2019
# 6801                        United States   January 24, 2020          2020
# 6930  United States, United Arab Emirates  November 23, 2019          2002
# 6027                               France        May 1, 2016          2015
#
#      rating   duration                                          listed_in  \
# 129   TV-MA    103 min     Horror Movies, International Movies, Thrillers
# 5799  TV-14   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 3531  TV-MA   1 Season                            Docuseries, TV Comedies
# 7638      R    100 min                         Dramas, Independent Movies
# 394   TV-MA     87 min       Comedies, International Movies, LGBTQ Movies
# 2261  TV-MA   1 Season  International TV Shows, Stand-Up Comedy & Talk...
# 4630  TV-14   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 6801  TV-MA  8 Seasons                             TV Comedies, TV Dramas
# 6930  PG-13     96 min               Action & Adventure, Sci-Fi & Fantasy
# 6027  TV-PG     98 min                Documentaries, International Movies
#
#                                             description
# 129   Six friends decide to undertake a grueling mou...
# 5799  Young entrepreneurs aspiring to launch virtual...
# 3531  Legendary comedy writer and director Larry Cha...
# 7638  In this unflinching noir drama, a resilient te...
# 394   In a small town, a trans teen with a vibrant p...
# 2261  In his farewell show, legendary German host Fr...
# 4630  Fighting to save his ancestors' mansion from d...
# 6801  Being a pro athlete didn't pan out for Colt. N...
# 6930  Based on the H.G. Wells classic, this adventur...
# 6027  This visually arresting documentary essay refl...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   object
#  10  listed_in     7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 730.2+ KB

# %%
df.describe()
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# 1.4) Checking Null Values 🔍🚫

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# 1.5) Handling Missing Values in each column

# %% [markdown]
# a.) missing "director" are filled with "Unknown"

# %%
df["director"] = df["director"].fillna("Unknown")

# %% [markdown]
# b.) Missing "cast" are filled with "Unknown"

# %%
df["cast"] = df["cast"].fillna("Unknown")

# %% [markdown]
# c.) Missing "country" are filled using mode

# %%
df["country"] = df["country"].fillna(df["country"].mode()[0])

# %% [markdown]
# d.) dropping rows with missing values in column "date_added" and "rating"

# %%
df.dropna(subset = ["date_added","rating"], inplace = True)

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# 1.6) Checking for Duplicate Enteries

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 2.) Column wise Exploration and Cleaning 🔍🧹

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# 2.1) show_id Column exploration and cleaning 🔍🧹

# %%
df["show_id"]
# Out:
# 0          s1
# 1          s2
# 2          s3
# 3          s4
# 4          s5
#         ...
# 7782    s7783
# 7783    s7784
# 7784    s7785
# 7785    s7786
# 7786    s7787
# Name: show_id, Length: 7770, dtype: object

# %%
df["show_id"].unique()
# Out:
# array(['s1', 's2', 's3', ..., 's7785', 's7786', 's7787'], dtype=object)

# %%
df["show_id"].nunique()
# Out:
# 7770

# %% [markdown]
# 2.2) "type" Column exploration and cleaning 🔍🧹

# %%
df["type"]
# Out:
# 0       TV Show
# 1         Movie
# 2         Movie
# 3         Movie
# 4         Movie
#          ...
# 7782      Movie
# 7783      Movie
# 7784      Movie
# 7785    TV Show
# 7786      Movie
# Name: type, Length: 7770, dtype: object

# %%
df["type"].unique()
# Out:
# array(['TV Show', 'Movie'], dtype=object)

# %%
df["type"].nunique()
# Out:
# 2

# %%
df["type"].value_counts()
# Out:
# type
# Movie      5372
# TV Show    2398
# Name: count, dtype: int64

# %%
df["type"].value_counts().plot(kind = 'pie', autopct ='%1.f',title = 'Types of content' )
plt.show()

# %% [markdown]
# 2.3) "title" Column exploration and cleaning 🔍🧹

# %%
df["title"]
# Out:
# 0                                            3%
# 1                                          7:19
# 2                                         23:59
# 3                                             9
# 4                                            21
#                          ...
# 7782                                       Zozo
# 7783                                     Zubaan
# 7784                          Zulu Man in Japan
# 7785                      Zumbo's Just Desserts
# 7786    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
# Name: title, Length: 7770, dtype: object

# %%
df["title"].unique()
# Out:
# array(['3%', '7:19', '23:59', ..., 'Zulu Man in Japan',
#        "Zumbo's Just Desserts", "ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS"],
#       dtype=object)

# %%
df["title"].nunique()
# Out:
# 7770

# %% [markdown]
# 2.4) "director" Column exploration and cleaning 🔍🧹

# %%
df["director"]
# Out:
# 0                 Unknown
# 1       Jorge Michel Grau
# 2            Gilbert Chan
# 3             Shane Acker
# 4          Robert Luketic
#               ...
# 7782          Josef Fares
# 7783          Mozez Singh
# 7784              Unknown
# 7785              Unknown
# 7786             Sam Dunn
# Name: director, Length: 7770, dtype: object

# %%
df["director"].unique()
# Out:
# array(['Unknown', 'Jorge Michel Grau', 'Gilbert Chan', ..., 'Josef Fares',
#        'Mozez Singh', 'Sam Dunn'], dtype=object)

# %%
df["director"].nunique()
# Out:
# 4048

# %%
df["director"].value_counts()
# Out:
# director
# Unknown                   2376
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Jay Karas                   14
# Cathy Garcia-Molina         13
#                           ...
# John Trengove                1
# Jonathan Helpert             1
# Jacob Schwab                 1
# Serge Ou                     1
# Eugenio Derbez               1
# Name: count, Length: 4048, dtype: int64

# %% [markdown]
# 2.5) "cast" Column exploration and cleaning 🔍🧹

# %%
df["cast"]
# Out:
# 0       João Miguel, Bianca Comparato, Michel Gomes, R...
# 1       Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2       Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3       Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4       Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
#                               ...
# 7782    Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                                              Nasty C
# 7785                           Adriano Zumbo, Rachel Khoo
# 7786                                              Unknown
# Name: cast, Length: 7770, dtype: object

# %%
df["cast"].unique()
# Out:
# array(['João Miguel, Bianca Comparato, Michel Gomes, Rodolfo Valente, Vaneza Oliveira, Rafael Lozano, Viviane Porto, Mel Fronckowiak, Sergio Mamberti, Zezé Motta, Celso Frateschi',
#        'Demián Bichir, Héctor Bonilla, Oscar Serrano, Azalia Ortiz, Octavio Michel, Carmen Beato',
#        'Tedd Chan, Stella Chung, Henley Hii, Lawrence Koh, Tommy Kuan, Josh Lai, Mark Lee, Susan Leong, Benjamin Lim',
#        ...,
#        'Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanana, Manish Chaudhary, Meghna Malik, Malkeet Rauni, Anita Shabdish, Chittaranjan Tripathy',
#        'Nasty C', 'Adriano Zumbo, Rachel Khoo'], dtype=object)

# %%
df["cast"].nunique()
# Out:
# 6818

# %% [markdown]
# 2.6) "country" Column exploration and cleaning 🔍🧹

# %%
df["country"]
# Out:
# 0                                                  Brazil
# 1                                                  Mexico
# 2                                               Singapore
# 3                                           United States
# 4                                           United States
#                               ...
# 7782    Sweden, Czech Republic, United Kingdom, Denmar...
# 7783                                                India
# 7784                                        United States
# 7785                                            Australia
# 7786                United Kingdom, Canada, United States
# Name: country, Length: 7770, dtype: object

# %%
df["country"].nunique()
# Out:
# 681

# %%
df["country"].value_counts()
# Out:
# country
# United States                                     3051
# India                                              923
# United Kingdom                                     396
# Japan                                              224
# South Korea                                        183
#                                                   ...
# Germany, United States, United Kingdom, Canada       1
# Peru, United States, United Kingdom                  1
# Saudi Arabia, United Arab Emirates                   1
# United Kingdom, France, United States, Belgium       1
# France, Norway, Lebanon, Belgium                     1
# Name: count, Length: 681, dtype: int64

# %%
df["country"].value_counts().head(10).plot(kind = 'bar',title = 'Top 10 Countries')
plt.show()

# %% [markdown]
# 2.7) "date_added" column exploration and cleaning

# %%
df["date_added"]
# Out:
# 0          August 14, 2020
# 1        December 23, 2016
# 2        December 20, 2018
# 3        November 16, 2017
# 4          January 1, 2020
#                ...
# 7782      October 19, 2020
# 7783         March 2, 2019
# 7784    September 25, 2020
# 7785      October 31, 2020
# 7786         March 1, 2020
# Name: date_added, Length: 7770, dtype: object

# %% [markdown]
# a) Converting 'date_added' to datetime objects

# %%
df["date_added"] = pd.to_datetime(df["date_added"], format = 'mixed',dayfirst = False)

# %% [markdown]
# b) Create new features for year and month added

# %%
df["year_added"] = df["date_added"].dt.year
df["month_added"] = df["date_added"].dt.month

# %%
df
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0               Unknown  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784            Unknown                                            Nasty C
# 7785            Unknown                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                            Unknown
#
#                                                 country date_added  \
# 0                                                Brazil 2020-08-14
# 1                                                Mexico 2016-12-23
# 2                                             Singapore 2018-12-20
# 3                                         United States 2017-11-16
# 4                                         United States 2020-01-01
# ...                                                 ...        ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar... 2020-10-19
# 7783                                              India 2019-03-02
# 7784                                      United States 2020-09-25
# 7785                                          Australia 2020-10-31
# 7786              United Kingdom, Canada, United States 2020-03-01
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description  year_added  \
# 0     In a future where the elite inhabit an island ...        2020
# 1     After a devastating earthquake hits Mexico Cit...        2016
# 2     When an army recruit is found dead, his fellow...        2018
# 3     In a postapocalyptic world, rag-doll robots hi...        2017
# 4     A brilliant group of students become card-coun...        2020
# ...                                                 ...         ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...        2020
# 7783  A scrappy but poor boy worms his way into a ty...        2019
# 7784  In this documentary, South African rapper Nast...        2020
# 7785  Dessert wizard Adriano Zumbo looks for the nex...        2020
# 7786  This documentary delves into the mystique behi...        2020
#
#       month_added
# 0               8
# 1              12
# 2              12
# 3              11
# 4               1
# ...           ...
# 7782           10
# 7783            3
# 7784            9
# 7785           10
# 7786            3
#
# [7770 rows x 14 columns]

# %% [markdown]
# 2.8) "release_year" column exploration and cleaning

# %%
df["release_year"]
# Out:
# 0       2020
# 1       2016
# 2       2011
# 3       2009
# 4       2008
#         ...
# 7782    2005
# 7783    2015
# 7784    2019
# 7785    2019
# 7786    2019
# Name: release_year, Length: 7770, dtype: int64

# %%
df["release_year"].unique()
# Out:
# array([2020, 2016, 2011, 2009, 2008, 2019, 1997, 2017, 2018, 2014, 2015,
#        2010, 2005, 2013, 2012, 2006, 2000, 2003, 1989, 2004, 1977, 1971,
#        1993, 2007, 1998, 1988, 1996, 2002, 1986, 1990, 1979, 1980, 1974,
#        2001, 1999, 1966, 1991, 1982, 1994, 1995, 1978, 1992, 1972, 1975,
#        2021, 1973, 1967, 1960, 1981, 1958, 1976, 1968, 1956, 1985, 1965,
#        1984, 1983, 1987, 1945, 1946, 1962, 1925, 1942, 1969, 1955, 1963,
#        1964, 1954, 1970, 1944, 1947, 1959, 1943])

# %%
df["release_year"].nunique()
# Out:
# 73

# %%
df["release_year"].value_counts()
# Out:
# release_year
# 2018    1120
# 2017    1010
# 2019     996
# 2016     881
# 2020     868
#         ...
# 1966       1
# 1925       1
# 1964       1
# 1947       1
# 1959       1
# Name: count, Length: 73, dtype: int64

# %%
df["release_year"].value_counts().head(10).plot(kind = 'bar', title = "Top 10 Release Year")
plt.show()

# %% [markdown]
# 2.9) "rating" column exploration and cleaning

# %%
df["rating"]
# Out:
# 0       TV-MA
# 1       TV-MA
# 2           R
# 3       PG-13
# 4       PG-13
#         ...
# 7782    TV-MA
# 7783    TV-14
# 7784    TV-MA
# 7785    TV-PG
# 7786    TV-MA
# Name: rating, Length: 7770, dtype: object

# %%
df["rating"].nunique()
# Out:
# 14

# %%
df["rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y',
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       2861
# TV-14       1928
# TV-PG        804
# R            665
# PG-13        386
# TV-Y         279
# TV-Y7        270
# PG           247
# TV-G         194
# NR            83
# G             39
# TV-Y7-FV       6
# UR             5
# NC-17          3
# Name: count, dtype: int64

# %%
df["rating"].value_counts().plot(kind = 'bar', title = 'Rating Distribution', figsize = (12,12))
plt.show()

# %% [markdown]
# 2.10) "duration" column exploration and cleaning 🔍🧹

# %%
df["duration"]
# Out:
# 0       4 Seasons
# 1          93 min
# 2          78 min
# 3          80 min
# 4         123 min
#           ...
# 7782       99 min
# 7783      111 min
# 7784       44 min
# 7785     1 Season
# 7786       90 min
# Name: duration, Length: 7770, dtype: object

# %%
df["duration"].nunique()
# Out:
# 216

# %% [markdown]
# 2.11) "listed_in" column exploration and cleaning 🔍🧹

# %%
df["listed_in"]
# Out:
# 0       International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                            Dramas, International Movies
# 2                     Horror Movies, International Movies
# 3       Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                  Dramas
#                               ...
# 7782                         Dramas, International Movies
# 7783       Dramas, International Movies, Music & Musicals
# 7784    Documentaries, International Movies, Music & M...
# 7785                   International TV Shows, Reality TV
# 7786                      Documentaries, Music & Musicals
# Name: listed_in, Length: 7770, dtype: object

# %%
df["listed_in"].nunique()
# Out:
# 491

# %%
genre = []
for i in df['listed_in']:
  genre = genre + i.split(',')

len(genre)
pd.Series(genre).value_counts().head(10).plot(kind ='bar')
# Out:
# <Axes: >

# %% [markdown]
# 3.) Data Analysis

# %% [markdown]
# 3.1) What is the distribution of content type?

# %%
type_counts = df['type'].value_counts()
plt.pie(type_counts, labels = type_counts.index, autopct ='%1.1f%%')
plt.title("distribution of content-type")
plt.show()

# %% [markdown]
# 3.2) How has content been added over time?

# %%
content_over_time = df.groupby(['year_added', 'type']).size().unstack().fillna(0)

plt.figure(figsize=(14, 8))
content_over_time.plot(kind='line', marker='o', figsize=(14, 8))
plt.title('Content Added to Netflix Over the Years (by Type)')
plt.xlabel('Year Added')
plt.ylabel('Number of Titles Added')
plt.legend(title='Content Type')
plt.grid(True)
plt.show()

# %% [markdown]
# 3.3) What are most popular geners?

# %%
genres = df.assign(genre=df['listed_in'].str.split(', ')).explode('genre')

# %%
genre_count = genres['genre'].value_counts().reset_index().head(15)
genre_count.columns = ['genre', 'count']

# %%
plt.figure(figsize=(12, 8))
sns.barplot(y='genre', x='count', data=genre_count, palette='mako', hue='genre', legend=False)
plt.title('Top 15 Genres on Netflix')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# 3.4) What is the distribution of content duration?

# %%
movies_df = df[df['type'] == 'Movie'].copy()
movies_df['duration_min'] = movies_df['duration'].str.replace(' min', '').astype(int)

# %%
tv_shows_df = df[df['type'] == 'TV Show'].copy()
tv_shows_df['seasons'] = tv_shows_df['duration'].str.replace(' Seasons', '').str.replace(' Season', '').astype(int)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))

sns.histplot(ax=axes[0], data=movies_df, x='duration_min', bins=50, kde=True, color='skyblue').set_title('Movie Duration Distribution (minutes)')
sns.countplot(ax=axes[1], x='seasons', data=tv_shows_df, palette='rocket', order=tv_shows_df['seasons'].value_counts().index, hue='seasons', legend=False).set_title('TV Show Season Distribution')

plt.show()

# %% [markdown]
# 3.5) Where does the content come from? (Geographical Analysis)

# %%
top_countries = df['country'].value_counts().reset_index()
top_countries.columns = ['country', 'count']
plt.figure(figsize = (12,8))
plt.title("Top 15 Content producing Countries on netflix")
plt.xlabel('number of Titles')
plt.ylabel('country')
sns.barplot(x = 'count', y= 'country', hue = 'country', data = top_countries.head(15),palette='viridis', legend = False)
plt.show()

# %% [markdown]
# 3.6) What are the maturity Rating of the contents?

# %%
plt.figure(figsize=(12, 8))
sns.countplot(x='rating', data=df, order=df['rating'].value_counts().index, palette='crest', hue='rating', legend=False)
plt.title('Distribution of Content Ratings on Netflix')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 3.7) Distribution of age of content when added to netflix.

# %%
df['age_on_netflix'] = df['year_added'] - df['release_year']

# Filter out any potential errors where added_year is before release_year
content_age = df[df['age_on_netflix'] >= 0]

plt.figure(figsize=(14, 7))
sns.histplot(data=content_age, x='age_on_netflix', bins=50, kde=True)
plt.title('Distribution of Content Age When Added to Netflix')
plt.xlabel('Content Age (Years)')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# 3.8) Theme and words most common on netflix content descriptions.

# %%
from wordcloud import WordCloud
text = ' '.join(df['description'])
wordcloud = WordCloud(width=800, height=400, background_color='black').generate(text)
plt.figure(figsize=(15, 10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Words in Netflix Content Descriptions', fontsize=20)
plt.show()
